# %% [markdown]
# ### NanoCube Benchmark
# #### Pandas DataFrame vs. NanoCube for OLAP-style point queries
# This benchmark compares the execution times of Pandas vs NanoCube for multiple different types of point queries
# on a randomly generated dataframe. Depending on argument `max_rows` the benchmark will generate and benchmark dataframes
# of different sizes, starting at 100 rows and doubling the size per iteration until reaching the specified number of rows.

# %%
from benchmark import Benchmark

Benchmark(max_rows=14_000_000).run()
# Out:
# Running benchmarks. Please wait...
# ...with 100 rows and 10 loops, cube init. in 0.00291 sec, overall in 0.01938 sec.
# ...with 200 rows and 10 loops, cube init. in 0.00144 sec, overall in 0.01316 sec.
# ...with 400 rows and 10 loops, cube init. in 0.00244 sec, overall in 0.01462 sec.
# ...with 800 rows and 10 loops, cube init. in 0.00440 sec, overall in 0.01899 sec.
# ...with 1,600 rows and 10 loops, cube init. in 0.00889 sec, overall in 0.02829 sec.
# ...with 3,200 rows and 10 loops, cube init. in 0.01604 sec, overall in 0.04264 sec.
# ...with 6,400 rows and 10 loops, cube init. in 0.03254 sec, overall in 0.07545 sec.
# ...with 12,800 rows and 10 loops, cube init. in 0.07520 sec, overall in 0.15254 sec.
# ...with 25,600 rows and 10 loops, cube init. in 0.15928 sec, overall in 0.30178 sec.
# ...with 51,200 rows and 10 loops, cube init. in 0.30823 sec, overall in 0.57770 sec.
# ...with 102,400 rows and 10 loops, cube init. in 0.59457 sec, overall in 1.13372 sec.
# ...with 204,800 rows and 10 loops, cube init. in 1.17826 sec, overall in 2.23388 sec.
# ...with 409,600 rows and 10 loops, cube init. in 2.32417 sec, overall in 4.38039 sec.
# ...with 819,200 rows and 10 loops, cube init. in 4.66300 sec, overall in 8.78071 sec.
# ...with 1,638,400 rows and 10 loops, cube init. in 10.69450 sec, overall in 18.85437 sec.
# ...with 3,276,800 rows and 10 loops, cube init. in 23.86852 sec, overall in 40.38550 sec.
# ...with 6,553,600 rows and 10 loops, cube init. in 50.82325 sec, overall in 83.23265 sec.
# ...with 13,107,200 rows and 10 loops, cube init. in 110.74913 sec, overall in 177.16564 sec.
